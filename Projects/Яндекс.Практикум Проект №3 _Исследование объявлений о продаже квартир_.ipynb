# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Артем :)
#
# Спасибо за работу на проекте, за все исправления и комментарии
#
# На этапе предобработки стоит использовать больше гистограмм, чтобы оценить качество данных, добавил одну подсказку плюс одну подсказку про среднюю скорость
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Артем :) Спасибо за доработки
#
# Критические ❌ комментарии
#
# + завершить фильтрацию редких значений в п. 2.4
#
# Добавил подсказки и бонус

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Артем :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...
#
# * Слева от проекта можно наблюдать вкладку **Contents**. Изначально она отсутствовала. Каким способом у тебя получилось её отобразить?
# * Можешь по возможности удалить рамку у некритичных комментариев (чтобы они были менее заметными) рядом с теми ячейками с кодом, которые уже исправлены?

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Нет рамку удалить не могу, попробую добавить рядом ✔, если некритичный комментарий исправлен

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Нажал на кнопку Table of Contents справа от Validate
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.
#
# **План проекта**:
#  1) Получение данных \
#  2) Предобработка данных \
#  3) Добавление новых столбцов в данные \
#  4) Исследовательский анализ данных \
#  5) Общий вывод

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Получим данные безопасным способом при помощи конструкции try-except
try:
    data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит делить блок загрузки библиотек и код загрузки датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />✔

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Построим гисограммы для всех числовых столбцов. То есть для всех столбцов, кроме `first_day_exposition`, `is_apartment`, `studio`, `open_plan`, `locality_name`.

# %%
# Для того, чтобы не выводить лишнюю информацию будем использовать `;`
data.hist(figsize=(15, 20));

# %% [markdown]
# Благодаря выводу метода `info()` можно заметить большое количество пропусков в данных. Также можно заметить несоответствие типов данных в нескольких столбцах и нарушение правила хорошего стиля в названиях столбцов. Все эти проблемы обработаем на следующем этапе - предобработке данных.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> не помешает добавить вывод после первого знакомства с данными

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />✔

# %% [markdown]
# ### Предобработка данных

# %%
# Переименуем названия столбцов в соответствии с правилами хорошего стиля
data.rename(columns={'cityCenters_nearest': 'city_centers_nearest'}, inplace=True)
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Красота стиля важна для серъезных проектов, молодец

# %% [markdown]
# #### Удаление пропусков

# %%
# Определим столбцы с пропусками и посчитаем количество пропущенных значений для каждого столбца
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Различают следующие 3 механизма формирования пропусков:
# 1. **MCAR**. Механизм формирования пропусков, при котором вероятность пропуска для каждой записи набора одинакова. Столбцы, которые имеют такой механизм формирования пропусков:
#     - `ceiling_height`
#     - `is_apartment`
#     - `balcony`
#     - `days_exposition`
#
#
# 2. **MAR**. Механизм формирования пропусков, при котором вероятность пропуска может быть определена на основе другой имеющейся в наборе данных информации, не содержащей пропуски. Столбцы, которые имеют такой механизм формирования пропусков:
#     - `locality_name`
#     - `airports_nearest`
#     - `parks_nearest`
#     - `ponds_nearest`
#
#
# 3. **MNAR**. Механизм формирования пропусков, при котором вероятность пропуска могла бы быть описана на основе других атрибутов, но информация по этим атрибутам в наборе данных отсутствует (например, объект недвижимости может иметь подземный этаж или чердак, но такая информация в наборе данных отсутствует). Столбцы, которые имеют такой механизм формирования пропусков:
#     - `floors_total`
#     - `living_area`
#     - `kitchen_area`
#     - `city_centers_nearest`
#     - `parks_around3000`
#     - `ponds_around3000`
#
# Будем разбираться с пропусками в столбцах по порядку, начиная с `ceiling_height` и заканчивая `days_exposition`

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?

# %% [markdown]
# Стоит добавить название графика - `title`

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# За поворот текста отвечает параметр rot, можно добавить обозначение оси х (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', tick_label='asd', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Процентное соотношение пропусков к общему числу строк' + "\n", fontsize = 22, color = 'SteelBlue')
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# ##### ceiling_height

# %% [markdown]
# Пропуски в столбце `ceiling_height` скорее всего имеют механизм формирования **MCAR**.

# %%
# Построим диаграмму размаха для столбца ceiling_height, чтобы понять как много выбросов содержится в данных
data.plot(kind='box', y='ceiling_height', ylim=(1.5, 3.75), figsize=(12, 4), grid=True);

# %% [markdown]
# На диаграмме размаха отчётливо видно огромное количество выбросов. Среднее арифметическое значение может некорректно характеризовать данные в такой ситуации. Поэтому для заполнения пропусков лучше использовать медианну. Но пропусков в столбце `ceiling_height` слишком много, поэтому их замена на медианное или среднее значение может сильно изменить распределение значений всего столбца. Поэтому оставим пропуски незаполненными.

# %% [markdown]
# ![%D0%A0%D0%B0%D1%81%D0%BF%D1%80%D0%B5%D0%B4%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%B4%D0%BE%20%D0%B8%D1%81%D0%BA%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D1%8F.svg](attachment:%D0%A0%D0%B0%D1%81%D0%BF%D1%80%D0%B5%D0%B4%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%B4%D0%BE%20%D0%B8%D1%81%D0%BA%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D1%8F.svg)

# %% [markdown]
# ![%D0%A0%D0%B0%D1%81%D0%BF%D1%80%D0%B5%D0%B4%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BF%D0%BE%D1%81%D0%BB%D0%B5%20%D0%B8%D1%81%D0%BA%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D1%8F.svg](attachment:%D0%A0%D0%B0%D1%81%D0%BF%D1%80%D0%B5%D0%B4%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BF%D0%BE%D1%81%D0%BB%D0%B5%20%D0%B8%D1%81%D0%BA%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D1%8F.svg)

# %% [markdown]
# ##### floors_total

# %% [markdown]
# Пропуски в столбце `floors_total` скорее всего имеют механизм формирования **MNAR**. Возможно наличие чердака или подземных этажей помешало точно указать общее количество этажей. В таком случае нам не хватает данных для того, чтобы правильно заполнить пропуски в данном столбце. Можно заметить, что количество пропусков достаточно мало (всего `86` строк). Наши данные не сильно пострадают, если мы удалим все строки, которые содержат пропуски в столбце `floors_total`.

# %%
data.dropna(subset=['floors_total'], inplace=True)

# %% [markdown]
# ##### living_area

# %% [markdown]
# Пропуски в столбце `living_area` скорее всего имеют механизм формирования **MNAR**. На рынке недвижимости Санкт-Петербурга существует достаточно большое количество квартир без гостинной комнаты (информация о наличии гостинной в данных отсутсвует). Именно у таких квартир может наблюдатся пропущенное значение в столбце `living_area`. Сделаем предположение, что значения в таблице пропущены только по причине отсутсвия гостинной комнаты. Это предположение позволит нам устранить пропуски в этом столбец. Приравняем значение жилой площади для объекта недвижимости без гостинной нулём.

# %%
data.living_area.fillna(0.0, inplace=True)

# %% [markdown]
# ##### is_apartment

# %% [markdown]
# Пропуски в столбце `is_apartment` скорее всего имеют механизм формирования **MCAR**. Большинство квартир не являются апартаментами. Как правило, если в объявлении продаются апартаменты, то скорее всего продавец явно это указывает. Значит можно предположить, что все (или почти все) объекты недвижимости с пропусками в столбце `is_apartment` на самом деле не являются апартаментами. Заменим все пропуски в столбце `is_apartment` на `False`.

# %%
data.is_apartment.fillna(False, inplace=True)

# %% [markdown]
# ##### kitchen_area

# %% [markdown]
# Пропуски в столбце `kitchen_area` скорее всего имеют механизм формирования **MNAR**. Аналогично случаю c отсутсвием гостинной комнаты приравняем значение кухонной площади для объекта недвижимости без кухни нулём.

# %%
data.kitchen_area.fillna(0.0, inplace=True)

# %% [markdown]
# ##### balcony

# %% [markdown]
# Пропуски в столбце `balcony` скорее всего имеют механизм формирования **MCAR**. Если продавец не указал число балконов, то, скорее всего, в его квартире их нет. Заменим все пропуски в столбце `balcony` на `0.0`.

# %%
data.balcony.fillna(0.0, inplace=True)

# %% [markdown]
# ##### locality_name

# %% [markdown]
# Пропуски в столбце `locality_name` скорее всего имеют механизм формирования **MAR**. Столбец `locality_name` имеет очень малое количество пропусков (всего 49 строк). Исследуя значения других столбцов можно заметить закономерность в данных и частично восстановить данный столбец. Все восстановленные пропущенные значения - это `Санкт-Петербург`. Заменим все пропуски в столбце `locality_name` на `Санкт-Петербург`.

# %%
# Таблица, которая позволяет проследить закономерность и частично восстановить пропуски в столбце locality_name
city_centers_distances = [1322.0, 3801.0, 3902.0, 4069.0, 4805.0, 8582.0, 8619.0, 12332.0]
(data
    .query('city_centers_nearest in @city_centers_distances')
    .sort_values(by='city_centers_nearest')
     [['locality_name', 'airports_nearest', 'city_centers_nearest', 'ponds_nearest']]
)
# Out:
#          locality_name  airports_nearest  city_centers_nearest  ponds_nearest
# 16610              NaN           21219.0                1322.0          365.0
# 11094  Санкт-Петербург           21219.0                1322.0          365.0
# 13464  Санкт-Петербург           24234.0                3801.0            NaN
# 9821               NaN           24953.0                3801.0          532.0
# 11869  Санкт-Петербург           24953.0                3801.0          532.0
# 1531   Санкт-Петербург           25054.0                3902.0          722.0
# 4151               NaN           25054.0                3902.0          722.0
# 17235  Санкт-Петербург           24070.0                3902.0            NaN
# 9541   Санкт-Петербург           25054.0                3902.0          722.0
# 12126  Санкт-Петербург           25054.0                3902.0          722.0
# 11248              NaN           25221.0                4069.0          653.0
# ...

# %%
data.locality_name.fillna('Санкт-Петербург', inplace=True)

# %% [markdown]
# ##### airports_nearest

# %% [markdown]
# Пропуски в столбце `airports_nearest` скорее всего имеют механизм формирования **MAR**. Так как большинство населённых пунктов в столбце `locality_name` достаточно небольшие по своему размеру, мы можем принебречь расположением объекта недвижимости внутри её населенного пункта. Тогда можно приравнять расстояние от квартиры до аэропорта с расстоянием от населённого пункта до аэропорта. При помощи поисковой выдачи и онлайн карт в сети интернет найдём такие расстояния для часто встречающихся населённых пунктов и таким образом восстановим большую часть пропусков.

# %%
data[data.airports_nearest.isna()].locality_name.value_counts().sort_values(ascending=False).head(50)
# Out:
# посёлок Мурино                             520
# Всеволожск                                 398
# Гатчина                                    307
# деревня Кудрово                            299
# Выборг                                     237
# Кудрово                                    171
# деревня Новое Девяткино                    143
# Сертолово                                  142
# Кириши                                     125
# Сланцы                                     112
# Волхов                                     111
# Тосно                                      104
# Кингисепп                                  104
# Никольское                                  93
# Санкт-Петербург                             92
# Коммунар                                    89
# Сосновый Бор                                87
# Кировск                                     84
# Отрадное                                    80
# посёлок Бугры                               68
# ...

# %%
airports_distances = {
    'посёлок Мурино': 29000.0,
    'Всеволожск': 33000.0,
    'Гатчина': 24000.0,
    'деревня Кудрово': 18000.0,
    'Выборг': 49000.0,
    'Кудрово': 23000.0,
    'деревня Новое Девяткино': 42000.0,
    'Сертолово': 39000.0,
    'Кириши': 125000.0,
    'Сланцы': 174000.0,
    'Волхов': 134000.0,
    'Кингисепп': 119000.0,
    'Тосно': 46000.0,
    'Никольское': 32000.0,
    'Санкт-Петербург': 16000.0,
    'Коммунар': 21000.0,
    'Сосновый Бор': 80850.0,
    'Кировск': 34000.0,
    'Отрадное': 35000.0,
    'посёлок Бугры': 44000.0,
    'Приозерск': 121000.0,
    'деревня Старая': 24000.0,
    'городской посёлок Янино-1': 12000.0,
    'Шлиссельбург': 51000.0,
    'Луга': 104000.0,
    'Тихвин': 176000.0,
    'поселок Бугры': 44000.0,
    'посёлок Тельмана': 21300.0,
    'Волосово': 59000.0,
    'поселок Романовка': 49000.0,
    'Мурино': 29000.0,
    'поселок Мурино': 29000.0,
    'посёлок городского типа Сиверский': 51300.0,
    'Ивангород': 33300.0,
    'городской посёлок Мга': 43700.0,
    'городской посёлок Новоселье': 20300.0,
    'поселок городского типа имени Свердлова': 21800.0,
    'Сясьстрой': 117700.0,
    'посёлок городского типа Кузьмоловский': 37200.0,
    'посёлок Щеглово': 37000.0,
    'поселок городского типа Синявино': 46310.0,
    'деревня Лесколово': 33700.0,
    'Лодейное Поле': 190000.0,
    'деревня Вартемяги': 24400.0,
    'посёлок Новогорелово': 6500.0,
    'поселок городского типа Рощино': 57400.0,
    'Подпорожье': 227600.0,
    'Пикалёво': 213900.0,
    'посёлок Сосново': 66900.0,
    'посёлок Новый Свет ': 120000.0
}

for key in airports_distances:
    data.loc[data.locality_name == key, 'airports_nearest'] = airports_distances[key]

# %% [markdown]
# ##### city_centers_nearest, parks_around3000, ponds_around3000

# %% [markdown]
# Пропуски в столбцах `city_centers_nearest`, `parks_around3000`, `ponds_around300` скорее всего имеют механизм формирования **MNAR** (например, если бы мы знали номер дома и улицу, на которой расположен объект недвижимости, то смогли бы восстановить расстояние до центра города, но такой информации в данных у нас нет). Мы не можем узнать точно где находится квартира, поэтому восстановить пропуск в столбце `city_centers_nearest` у нас не получится. Аналогично со столбцами `parks_around3000` и `ponds_around3000`. Так как пропусков в этих столбцах слишком много, оставим их без изменений.

# %% [markdown]
# ##### parks_nearest, ponds_nearest

# %% [markdown]
# Пропуски в столбцах `parks_nearest` и `ponds_nearest` скорее всего имеют механизм формирования **MAR**. Пропуски в столбце `parks_nearest` и `ponds_nearest` появляются только тогда, когда в столбце `parks_around3000` и `ponds_around3000` значение равно `NaN` или `0.0`. Если парков или водоёмов рядом с объектом недвижимости нет, то мы можем заменить пропуски в столбце `parks_nearest` и `ponds_nearest` на `0.0`. Оставшуюся часть пропусков оставим без изменений.

# %%
data.loc[data.parks_around3000 == 0.0, 'parks_nearest'] = 0.0
data.loc[data.ponds_around3000 == 0.0, 'ponds_nearest'] = 0.0

# %% [markdown]
# ##### days_exposition

# %% [markdown]
# Пропуски в столбце `days_exposition` скорее всего имеют механизм формирования **MCAR**. Аналогично столбцу `ceiling_height` замена всех пропусков в столбце `days_exposition` на среднее, медианное или нулевое значение может очень сильно исказить распределение значений этого столбца. Поэтому оставим этот столбец без изменений.

# %%
# Снова посчитаем количество пропущенных значений для каждого столбца
data.isna().sum()
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height          9118
# floors_total               0
# living_area                0
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area               0
# balcony                    0
# locality_name              0
# airports_nearest        1212
# city_centers_nearest    5509
# parks_around3000        5508
# parks_nearest           5508
# ponds_around3000        5508
# ponds_nearest           5508
# days_exposition         3172
# dtype: int64

# %% [markdown]
# #### Изменение типов данных

# %% [markdown]
# - поменяем тип данных в столбце `first_day_exposition` на `datetime64[ns]` для того, чтобы в дальнейшем мы могли совершать арифметические операции с датами из этого столбца.
# - поменяем тип данных в столбцах `last_price`, `floors_total`,  `balcony` на `int64` потому, что значения в этих столбцах должны принимать только целочисленные значения.

# %%
data = data.astype({
    'last_price': 'int64',
    'first_day_exposition': 'datetime64[ns]',
    'floors_total': 'int64',
    'balcony': 'int64',
})

# Проверим типы данных для всех столбцов
data.dtypes
# Out:
# total_images                     int64
# last_price                       int64
# total_area                     float64
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float64
# floors_total                     int64
# living_area                    float64
# floor                            int64
# is_apartment                      bool
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                          int64
# locality_name                   object
# airports_nearest               float64
# city_centers_nearest           float64
# parks_around3000               float64
# parks_nearest                  float64
# ponds_around3000               float64
# ponds_nearest                  float64
# days_exposition                float64
# dtype: object

# %% [markdown]
# #### Обработка дубликатов

# %%
# Изучим уникальные значения в столбце locality_name для того, чтобы устранить неявные дубликаты
data.locality_name.sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %% [markdown]
# Для того чтобы избавиться от неявных дубликатов в столбце `locality_name` произведём несколько замен в подстроках значений этого столбца. Будем различать деревни, посёлки, садовые товарищества и сёла с одинаковыми названиями. Произведём соответсвующие замены в тех случаях, когда они совпадают по местоположению.

# %%
substrings = [
    ('городской поселок', 'посёлок'), 
    ('городской посёлок', 'посёлок'),
    ('коттеджный поселок', 'посёлок'),
    ('коттеджный посёлок', 'посёлок'),
    ('поселок городского типа имени', 'посёлок'),
    ('поселок городского типа', 'посёлок'),
    ('посёлок городского типа имени', 'посёлок'),
    ('посёлок городского типа', 'посёлок'),
    ('посёлок при железнодорожной станции', 'посёлок'),
    ('поселок станции', 'посёлок'),
    ('посёлок станции', 'посёлок'),
    ('поселок', 'посёлок'),
    ('садоводческое некоммерческое товарищество', 'садовое товарищество'),
    ('деревня Кудрово', 'Кудрово'),
    ('посёлок Любань', 'Любань'),
    ('посёлок Мурино', 'Мурино'),
    ('деревня Гарболово', 'посёлок Гарболово'),
    ('деревня Фёдоровское', 'посёлок Фёдоровское'),
    ('деревня Щеглово', 'посёлок Щеглово'),
    ('садовое товарищество Приладожский', 'посёлок Приладожский'),
    ('садовое товарищество Рахья', 'посёлок Рахья')
]

for old_substring, new_substring in substrings:
    data.locality_name = data.locality_name.apply(lambda x: x.replace(old_substring, new_substring))

# %%
data.locality_name.sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'деревня Агалатово', 'деревня Аро', 'деревня Батово',
#        'деревня Бегуницы', 'деревня Белогорка', 'деревня Большая Вруда',
#        'деревня Большая Пустомержа', 'деревня Большие Колпаны',
#        'деревня Большое Рейзино', 'деревня Большой Сабск', 'деревня Бор',
#        'деревня Борисова Грива', 'деревня Ваганово', 'деревня Вартемяги',
# ...

# %%
# check
data.locality_name.nunique()
# Out:
# 310

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Хорошая работа по избавлению от неявных дубликатов
#
#
# Можно отметить в отчете — стоит ли объединять нас. пункты
#
#         'деревня Кудрово'
#         'Кудрово'

# %%
# Проверим наличие строк-дубликатов в наших данных
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса
#
# __Оптимальнее поиск дубликатов выполнять после обработки неявных дубликатов__

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# Для того, __чтобы изменить лишь часть строки,__ можно добавить к коду — .str
#
#         .str.replace('посёлок','поселок')
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.replace.html

# %%
# Проверим наличие строк-дубликатов по сумме ключевых параметров в наших данных
data[(~data['city_centers_nearest'].isna()) &
     (data.duplicated(subset=['total_area', 'floor', 'floors_total', 'city_centers_nearest', 'locality_name', 'rooms']))]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3568             17     4950000        58.0           2018-02-20      3
# 3576              9     5250000        57.1           2015-04-06      3
# 5018              0     4200000        51.0           2016-11-26      2
# 5776              7    20000000        83.0           2017-09-06      3
# 6929              3    16177174       122.7           2015-12-14      3
# ...             ...         ...         ...                  ...    ...
# 23245             9     4950000        55.0           2017-11-20      2
# 23323            10     4300000        46.0           2017-07-20      1
# 23382             2    15000000       150.9           2016-07-04      4
# 23516             3    22529250       139.5           2018-07-04      4
# 23541            16     5200000        63.0           2017-10-27      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
data = data[(data['city_centers_nearest'].isna()) |
            (~data.duplicated(subset=['total_area', 'floor', 'floors_total', 'city_centers_nearest',
                                      'locality_name', 'rooms']))]

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# + дополнительно — на рабочих проектах стоит искать дубликаты по сумме ключевых параметров (подмножеству), для примера:
#
#  + общ. площадь квартиры,
#  + этаж,
#  + общая этажность дома,
#  + расстояние до центра
#  + название населенного пункта
#  + кол-во комнат
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Перед удалением стоит взглянуть на записи, м.б. это не такие уж дубликаты

# %% [markdown]
# #### Устранение аномальных значений

# %% [markdown]
# - `Q1` и `Q2` - квантили для отсечения аномальных значений
# - `total_images`: максимальное значение этого столбца равно `50`. Это редкое, но не аномальное значение. Оставим этот столбец без изменений.
# - `last_price`: Очистим этот столбец от таких аномальных значений, которые не входят в диапазон `(Q1, Q2)`
# - `total_area`: Очистим этот столбец от таких аномальных значений, которые не входят в диапазон `(Q1, Q2)`
# - `first_day_exposition`: все значения этого столбца находятся в диапазоне дат с `27.11.2014` до `03.05.2019`. Оставим этот столбец без изменений.
# - `rooms`: Очистим этот столбец от таких аномальных значений, которые не входят в диапазон `(Q1, Q2)`
# - `ceiling_height`: Значения в диапазоне от `20.0` до `32.0` скорее всего возникли из-за опечатки. Уменьшим их в десять раз. Очистим этот столбец от таких аномальных значений, которые не входят в диапазон `(Q1, Q2)`
# - `floors_total`: Очистим этот столбец от таких аномальных значений, которые не входят в диапазон `(Q1, Q2)`
# - `living_area`: Очистим этот столбец от таких аномальных значений, которые не входят в диапазон `(Q1, Q2)`
# - `floor`: Очистим этот столбец от таких аномальных значений, которые не входят в диапазон `(Q1, Q2)`
# - `kitchen_area`: Очистим этот столбец от таких аномальных значений, которые не входят в диапазон `(Q1, Q2)`
# - `balcony`: максимальное значение этого столбца равно `5`. Это редкое, но не аномальное значение. Оставим этот столбец без изменений.
# - `airports_nearest`: Очистим этот столбец от таких аномальных значений, которые не входят в диапазон `(Q1, Q2)`
# - `city_centers_nearest`: Очистим этот столбец от таких аномальных значений, которые не входят в диапазон `(Q1, Q2)`
# - `parks_around3000`: максимальное значение этого столбца равно `3.0`. Это редкое, но не аномальное значение. Оставим этот столбец без изменений.
# - `parks_nearest`: максимальное значение этого столбца равно `2984.0`. Это редкое, но не аномальное значение. Оставим этот столбец без изменений.
# - `ponds_around3000`: максимальное значение этого столбца равно `3.0`. Это редкое, но не аномальное значение. Оставим этот столбец без изменений.
# - `ponds_nearest`: максимальное значение этого столбца равно `1344.0`. Это редкое, но не аномальное значение. Оставим этот столбец без изменений.
# - `days_exposition`: Очистим этот столбец от таких аномальных значений, которые не входят в диапазон `(Q1, Q2)`

# %% [markdown]
# #### check nan

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23552 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23552 non-null  int64
#  1   last_price            23552 non-null  int64
#  2   total_area            23552 non-null  float64
#  3   first_day_exposition  23552 non-null  datetime64[ns]
#  4   rooms                 23552 non-null  int64
#  5   ceiling_height        14455 non-null  float64
#  6   floors_total          23552 non-null  int64
#  7   living_area           23552 non-null  float64
#  8   floor                 23552 non-null  int64
#  9   is_apartment          23552 non-null  bool
#  10  studio                23552 non-null  bool
#  11  open_plan             23552 non-null  bool
#  12  kitchen_area          23552 non-null  float64
#  13  balcony               23552 non-null  int64
#  14  locality_name         23552 non-null  object
# ...

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23552.000000  2.355200e+04  23552.000000  23552.000000    14455.000000
# mean       9.873047  6.530370e+06     60.300405      2.070355        2.771295
# std        5.680466  1.089939e+07     35.608469      1.078082        1.263076
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.510000
# 50%        9.000000  4.640000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.776250e+06     69.700000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23552.000000  23552.000000  23552.000000  23552.000000  23552.000000
# mean      10.677140     31.710701      5.877845      9.563758      0.592943
# ...

# %%
Q1 = 0.005
Q2 = 0.995

# Исправим аномальные значения возникшие из-за возможной опечатки
data.loc[(20.0 <= data.ceiling_height) & (data.ceiling_height <= 32.0), 'ceiling_height'] /= 10.0

# Очистим столбцы от аномальных значений, которые находятся за границами выбранных квантилей
# Не забудем при этом прибавить условие на записи с пропусками
# Условие на нулевые маркеры в данных столбцах проверять не будем
for column in ['last_price', 'total_area', 'rooms', 'ceiling_height',
               'floors_total', 'living_area', 'floor', 'kitchen_area',
               'airports_nearest', 'city_centers_nearest', 'days_exposition']:
    data = data[((data[column].quantile(Q1) <= data[column]) & (data[column] <= data[column].quantile(Q2))) |
                (data[column].isna()) | (data[column] == 0)]

# %%
# check
data.shape[0]
# Out:
# 22041

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#     data = data[(1.2 < data.ceiling_height) & (data.ceiling_height <= 10.3)]
#
# Так мы познакомились с особенностью фильтрации в библиотеке пандас, все NaN убегают вместе со значениями, которые не подходят под нашу фильтрацию, поэтому процент потери записей огромен
#
# Минус 9 000 записей
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками
#
# <b>алгоритм фильтрации столбца с пропусками: задаем основное условие фильтрации, + прибавляем условие не трогать записи с пропусками</b>
#
# стоит обратить внимание на весь код фильтрации, т.к. в нескольких колонках встречаются пропуски

# %% [markdown]
# #### check gap

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22041 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22041 non-null  int64
#  1   last_price            22041 non-null  int64
#  2   total_area            22041 non-null  float64
#  3   first_day_exposition  22041 non-null  datetime64[ns]
#  4   rooms                 22041 non-null  int64
#  5   ceiling_height        13524 non-null  float64
#  6   floors_total          22041 non-null  int64
#  7   living_area           22041 non-null  float64
#  8   floor                 22041 non-null  int64
#  9   is_apartment          22041 non-null  bool
#  10  studio                22041 non-null  bool
#  11  open_plan             22041 non-null  bool
#  12  kitchen_area          22041 non-null  float64
#  13  balcony               22041 non-null  int64
#  14  locality_name         22041 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max', 'median'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_c0e3c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c0e3c_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_c0e3c_row0_col0" class="data row0 col0" >22,041.00</td>
#                         <td id="T_c0e3c_row0_col1" class="data row0 col1" >22,041.00</td>
# ...

# %%
# check
data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5));

data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#          'rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area'
#
# для определения хвостов, редкостей и аномалий смотрим на минимальные и максимальные значения, строим несколько гистограмм по каждому параметру
#
# например в таблице мы видим аномалию квартиру за 12 тыс. руб. ..., а на гистограмме аномальную скорость продаж в один или два дня
#
# стоит учесть наличие пропусков и нулевые маркеры при фильтрации данных, их не стоит терять

# %%
# check
data.hist(column = 'kitchen_area', bins = 50, figsize = (15,3), range = (0.1,5));

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Все кухни до 5-ти кв. метров ... Стоит использовать гистограммы для определения хвостов и не удалить 2000 нулевых маркеров

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'
#
# стоит обратить внимание на минимальные и максимальные значения в выборке и учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Доп. задание, на твое усмотрение — сможешь добавить в таблицу расчет медианного значения?
#
#         (
#             data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
#                   'floor', 'floors_total']]
#             .apply (['count', 'min', 'max'])
#             .style.format("{:,.2f}")
#         )

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается, табличка стала твоей собственостью :)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, несколько записей со стоимостью квадратного метра выше 1-го млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %%
# check

try:
    df_check = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')
# если не получилось прочитать файл из локальной папки, то загружаем данные из сети
except:
    df_check = pd.read_csv('real_estate_data.csv', sep='\t')

# %%
# check
df_check.rooms.value_counts().to_frame()
# Out:
#     rooms
# 1    8047
# 2    7940
# 3    5814
# 4    1180
# 5     326
# 0     197
# 6     105
# 7      59
# 8      12
# 9       8
# 10      3
# 11      2
# 14      2
# 19      1
# 16      1
# 12      1
# 15      1

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 20-ти и более 250-ти квадратных метров можно считать редкостями

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (0,25));

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось завершить выполнение пункта 2.4 из брифа проекта
#
# 2.4.	Найдите и устраните редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__
#
# Если при фильтрации одной колонки, на этом проекте, теряем больше одного процента данных от изначального объема, стоит еще раз пересмотреть условия фильтрации

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# они помогают увидеть редкости и аномалии в данных

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
# Функция, которая поможет нам разбить столбец floor на категории по типу этажа
def floor_categorize(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'

# %% [markdown]
# На данном этапе после предобработки данных нулевые и отрицательные значения в столбец `floor` отсутсвуют. Поэтому дополнительная проверка таких значений будет избыточна.

# %%
category_to_num = {'первый': 0, 'последний': 1, 'другой': 2}
    
# Добавим в таблицу новые столбцы, которые понадобятся нам в дальнейшем
data['price_per_sqm'] = data.last_price / data.total_area
data['exposition_weekday'] = data.first_day_exposition.dt.weekday
data['exposition_month'] = data.first_day_exposition.dt.month
data['exposition_year'] = data.first_day_exposition.dt.year
data['floor_category'] = data.apply(floor_categorize, axis='columns')
data['floor_category_num'] = data['floor_category'].apply(lambda x: category_to_num[x])
data['city_centers_nearest_km'] = round(data.city_centers_nearest / 1000.0)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит делить код с функцией и остальным кодом, чтобы была возможность для отладки функции

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />✔

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Функция хорошая, стоит учесть крайние условия: нулевые и отрицательные значения

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />в следующем месяце мы можем работать с базой недвижимости Москвы или Торонто, в которых могут встретиться полуподвальные или подвальные помещения ... или нам предоставили только часть датасета ...
#
# универсальная функция ценится тем, что её программируют один раз, а используют множество раз
#
#           elif 1 < floor < floors_total:

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> данные добавлены корректно, молодец

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучение параметров

# %% [markdown]
# Для начала построим отдельные гистограммы для каждого из следующих параметров:
# - общая площадь
# - жилая площадь
# - площадь кухни
# - цена объекта
# - количество комнат
# - высота потолков
# - этаж квартиры
# - тип этажа квартиры
# - общее количество этажей в доме
# - расстояние до центра города в метрах
# - расстояние до ближайшего аэропорта
# - расстояние до ближайшего парка
# - день и месяц публикации объявления

# %% [markdown]
# ##### Гистограммы для параметров

# %%
# Для каждой гистограммы будем использовать свои значения bins и x_lim 
pd.DataFrame(columns=['plot_column', 'bins', 'xlim', 'ylim'], 
             data=[['total_area', 200, (0, 500), (0, 1400)],
                   ['living_area', 100, (0, 300), (0, 3500)],
                   ['kitchen_area', 100, (0, 100), (0, 2500)],
                   ['last_price', 400, (0, 80000000), (0, 1400)],
                   ['rooms', 16, (0, 15), (0, 9000)],
                   ['ceiling_height', 50, (1, 6), (0, 4000)],
                   ['floor', 60, (1, 60), (0, 3500)],
                   ['floor_category_num', 3, (0, 2), (0, 18000)],
                   ['floors_total', 60, (1, 60), (0, 6000)],
                   ['city_centers_nearest', 100, (0, 60000), (0, 1200)],
                   ['airports_nearest', 50, (10000, 120000), (0, 18000)],
                   ['parks_nearest', 100, (100, 1000), (0, 1000)],
                   ['exposition_weekday', 7, (0, 6), (0, 4500)],
                   ['exposition_month', 12, (1, 12), (0, 3000)]]).apply(lambda row: data.plot(kind='hist',
                                                                                              y=row['plot_column'],
                                                                                              bins=row['bins'],
                                                                                              xlim=row['xlim'],
                                                                                              ylim=row['ylim'],
                                                                                              figsize=(12, 4),
                                                                                              legend=True,
                                                                                              title=row['plot_column'],
                                                                                              grid=True), axis=1);

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошие графики, можно добавить кол-во корзин к параметрам гистограммы
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и
#
# [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> При отрисовке графиков стоит исключать значения-заглушки, которыми мы заполнили пропуски, они мешают рассматривать реальную картину
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Наблюдения

# %% [markdown]
# - Большинство объектов недвижимости находятся в Санкт-Петербурге. Это объясняет наличие пика на гистограмме параметра `airports_nearest`
# - Чаще всего объявления публикуются по будням, редко в выходные дни.
# - Можно заметить сезонность выставления объявлений в параметре `exposition_month`. Чаще всего объявления создаются в феврале, марте и апреле. Также можно наблюдать тренд увеличения количества создаваемых объявлений с июня по ноябрь. В начале зимы на рынке недвижимости царит затишье после осеннего ажиотажа. Но уже в феврале девелоперы стараются распродать то, что не удалось сбыть осенью. Это может быть потенциальной причиной повышенного количества объявлений в феврале.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно, почему февраль (самый короткий месяц) опережает все месяцы — ?__

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит смотреть на цифры и графики
#
# Можно посмотреть на каждый февраль из нашей выборки, а затем на каждый день особого февраля ..., можно захватить  и предыдущий январь

# %% [markdown]
# #### Изучаем столбец `days_exposition` (как быстро продавались квартиры)

# %% [markdown]
# ##### Гистограмма

# %%
data.days_exposition.plot(kind='hist', bins=150, xlim=(0, 1600), figsize=(12, 4), legend=True, grid=True);

# %% [markdown]
# ##### Ящик с усами

# %%
data.days_exposition.plot(kind='box', ylim=(0,700), figsize=(12, 4), legend=True, grid=True);
data.days_exposition.describe()
# Out:
# count    19146.000000
# mean       172.654654
# std        202.068890
# min          3.000000
# 25%         44.000000
# 50%         93.000000
# 75%        223.000000
# max       1166.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# ##### Среднее, медиана и модальное значение

# %%
print('Среднее значение столбца days_exposition:', data.days_exposition.mean())
print('Медианное значение столбца days_exposition:', data.days_exposition.median())
print('Модальное значение столбца days_exposition:', data.days_exposition.mode()[0])
# Out:
# Среднее значение столбца days_exposition: 172.65465371356942
# Медианное значение столбца days_exposition: 93.0
# Модальное значение столбца days_exposition: 45.00000000000001

# %%
data['days_exposition'].plot(kind='hist', bins=150, xlim=(0, 200), figsize=(12, 4), legend=True, grid=True);

# %% [markdown]
# Продажа обычно занимает от `45` до `248` дней. Необычно долгими можно считать продажи от `553` дней. Чаще всего продажа занимает около `45.0` дней. Далее посмотрим на изменение средней скорости продаж по годам.

# %%
exposition_increment = data.pivot_table(index='exposition_year', values='days_exposition', aggfunc='count').diff()
exposition_increment.columns = ['exposition_increment']
exposition_increment
# Out:
#                  exposition_increment
# exposition_year
# 2014                              NaN
# 2015                            861.0
# 2016                           1579.0
# 2017                           4935.0
# 2018                           -351.0
# 2019                          -6082.0

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Ты подсчитал кол-во объявлений, а не среднюю скорость

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
# __Интересно посмотреть на изменение средней  скорости продаж по годам__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не исследованы моды в 'days_exposition' и как они влияют на скорость продажи, подсказка на что смотреть
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %% [markdown]
# #### Факторы больше всего влияющие на общую (полную) стоимость объекта

# %%
data[['last_price', 'total_area', 'living_area', 'kitchen_area', 'rooms', 
      'floor_category_num', 'exposition_year']].corr()['last_price']
# Out:
# last_price            1.000000
# total_area            0.748108
# living_area           0.499614
# kitchen_area          0.438286
# rooms                 0.438852
# floor_category_num    0.110647
# exposition_year      -0.026031
# Name: last_price, dtype: float64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Коэффициент корреляции рассчитывается для всех зависимостей из задания, исключая параметры - день недели и месяц — это не эффективно, т.к. это нелинейные параметры
#
# чтобы они стали линейными, январь месяц 2015 года должен стать третьим и т.д., т.е. мы должны сделать перекодировку ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />✔

# %%
for column in ['kitchen_area', 'living_area', 'total_area']:
    (
        data.pivot_table(index='last_price', values=column, aggfunc='mean')
        .reset_index()
        .plot(kind='scatter',
              x='last_price',
              y=column,
              xlim=(0, 50000000),
              figsize=(12, 4),
              title=column,
              legend=True,
              grid=True)
    )
    plt.show()

# %%
for column in ['exposition_weekday', 'exposition_month', 'exposition_year']:
    data.groupby(column).last_price.mean().plot(figsize=(12, 4), title=column, legend=True, grid=True)
    plt.show()

# %%
for column in ['rooms', 'floor_category']:
    data.groupby(column).last_price.mean().plot(kind='bar', figsize=(12, 4), title=column, legend=True, grid=True)
    plt.show()

# %%
expositions_per_year = data.pivot_table(index='exposition_year', values='last_price', aggfunc='count')
expositions_per_year
# Out:
#                  last_price
# exposition_year
# 2014                     99
# 2015                    998
# 2016                   2581
# 2017                   7685
# 2018                   7975
# 2019                   2703

# %%
expositions_per_year.plot(kind='bar', figsize=(12, 4), title='Expositions per year', legend=True, grid=True);

# %%
area_per_year = data.pivot_table(index='exposition_year', values='total_area', aggfunc='mean')
area_per_year
# Out:
#                  total_area
# exposition_year
# 2014              79.664040
# 2015              62.786353
# 2016              58.491155
# 2017              56.864496
# 2018              55.675446
# 2019              55.991465

# %%
area_per_year.plot(kind='bar', figsize=(12, 4), title='Expositions per year', legend=True, grid=True);

# %% [markdown]
#  * `total_area`, `living_area`, `kitchen_area`, `rooms`, `floor_category`, `exposition_year` больше всего влияют на общую полную стоимость.
#  * Можно заметить, что квартиры на первом этаже как правило дешевле, чем квартиры на других этажах.
#  * С увеличением количества комнат растёт и цена объекта недвижимости.
#  * Цена на объекты недвижимости уменьшается с каждым годом вплоть до 2018 года. Цена - это параметр, на который влияет несколько других факторов. Например, можно заметить, что количество объявлений росло с 2014 по 2018 годы. Это могло повлиять на изменение цены на рынке недвижимости. Также изменение средней общей площади объектов недвижимости могло повлиять на изменение цен.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    Стоит добавить третий график про количество и поправить в тексте акценты вывода
#
# (выполнение доп. исследований — на твое усмотрение)
#
# Если смотреть только на изменение цены по годам мы можем сделать некорректный вывод, что цены падали, а на самом деле цена это параметр на который влияет несколько других факторов, по этой причине можно посмотреть на основные из них:
#
# + изменение кол-ва записей — принять решение о достаточности данных для анализа и сравнения (сравнивать 100 объявлений и 8000, а возможно, что они еще и из разных локаций, не совсем корректно)
# + изменение площади, как основного параметра от которого зависит стоимость квартиры, в 2017-2018 гг. на сервис или рынок ИТ-торговли недвижимостью пришел массовый продавец, и средние значения упали ..., а за ней и цена
# + изменение кол-ва поданных объявлений из разных локаций, т.к. есть питерские квартиры, а есть выборгские квартиры и стоят они по разному, и в разные годы могло быть больше квартир из определенной локации
# + полнота периода для анализа, 2014 и 2019 гг. неполные, а у нас есть сезонные колебания цен, например летнее снижение цен
# + изменение доли дорогих категорий в общей выборке (средние этажи)
#
# и т.д.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    Стоит добавить недостающие графики,  коэф. корреляции отображает лишь возможное наличие линейной связи
#
# Шаг 4. Проведите исследовательский анализ данных:
#
# 3.	Какие факторы больше всего влияют на общую (полную) стоимость объекта?
#     Изучите, зависит ли цена от:
#     +	общей площади;
#     +	жилой площади;
#     +	площади кухни;
#     +	количества комнат;
#     +	этажа, на котором расположена квартира (первый, последний, другой);
#     +	даты размещения (день недели, месяц, год).
#
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
#
#
#
# Советы по графикам:
#
# + зависимость параметров (от площади, удалённости от центра) оптимальнее рассматривать на точечных графиках (тип scatter),
# + динамику на линейных (это про сравнение цен за год, месяц, день недели), — стоит сгруппировать значения и рассчитать среднее или медианное значение
# + сравнение цен на барах (для сравнение средней стоимости квартиры по трем категориям), — стоит сгруппировать значения и рассчитать среднее или медианное значение

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />  Можно попробовать настроить вид точечных графиков
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)
#
# Примеры расчета коэф. корреляции и не только
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?ysclid=l9ev0utyg728177057)

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров: кол-во записей и изменение средней цены и средней площади в течение лет)

# %% [markdown]
# #### Подсчёт средней цены одного квадратного метра в различных населённых пунктах

# %%
# Подсчитаем среднюю цену одного квадратного метра в различных населённых пунктах
locality_sqm_price = data.pivot_table(index='locality_name', values='price_per_sqm', aggfunc='mean')

# %%
# Отфильтруем 10 населённых пунктов с наибольшим числом объявлений
top_10 = locality_sqm_price[locality_sqm_price.index.isin(data['locality_name'].value_counts().head(10).index)]
top_10 = top_10.sort_values(by='price_per_sqm', ascending=False)
top_10.round()
# Out:
#                    price_per_sqm
# locality_name
# Санкт-Петербург         111281.0
# Пушкин                  102814.0
# Кудрово                  95038.0
# посёлок Парголово        90153.0
# Мурино                   85924.0
# посёлок Шушары           77284.0
# Колпино                  75259.0
# Гатчина                  68852.0
# Всеволожск               68681.0
# Выборг                   58081.0

# %%
top_10.plot(kind='barh', figsize=(12, 4), rot=-2, title='Top 10 localities', legend=False, fontsize=16);

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />За поворот текста отвечает параметр rot, молодец что применяешь примеры

# %%
print('Населённый пункт с самой высокой стоимостью квадратного метра:', locality_sqm_price.idxmax()[0])
print('Населённый пункт с самой низкой стоимостью квадратного метра:', locality_sqm_price.idxmin()[0])
# Out:
# Населённый пункт с самой высокой стоимостью квадратного метра: Зеленогорск
# Населённый пункт с самой низкой стоимостью квадратного метра: деревня Малая Романовка

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#         Гатчина	69992.693801
#         Всеволожск	67344.467501

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />✔

# %% [markdown]
# #### Зависимость стоимости объектов от расстояния до центра города в километрах.

# %%
# Построим линейный график средней стоимости только питерских квартир на каждом километре
(
    data[data['locality_name'] == 'Санкт-Петербург']
    .groupby('city_centers_nearest_km')['last_price']
    .mean()
    .plot(use_index=True,
          y='city_centers_nearest_km',
          figsize=(12, 4),
          title='price_per_distance',
          legend=True,
          grid=True)
);

# %%
# Изучим объекты недвижимости на расстоянии 27 киллометров до центра
data[(data['city_centers_nearest_km'] == 27.0) & (data['locality_name'] == 'Санкт-Петербург')]
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 748             13    14350000        74.0           2017-11-28      2
# 5961             6     2250000        32.0           2018-02-27      1
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 748             3.13             5         30.0      3         False  ...
# 5961             NaN             2         16.5      2         False  ...
#
#       ponds_around3000  ponds_nearest  days_exposition  price_per_sqm  \
# 748                0.0            0.0            128.0  193918.918919
# 5961               0.0            0.0            178.0   70312.500000
#
#      exposition_weekday  exposition_month  exposition_year  floor_category  \
# 748                   1                11             2017          другой
# 5961                  1                 2             2018       последний
#
#       floor_category_num  city_centers_nearest_km
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается,
#
# у нас всего 2 записи на 27-м км., одна из которых с аномальной ценой, по этой причине мы отвергаем данное наблюдение
#
# __кол-во наблюдений важный параметр для оценки качества данных__

# %%
# Изучим объекты недвижимости на расстоянии 3 киллометра до центра
city_centers_nearest_3_km = data[(data['city_centers_nearest_km'] == 3.0) & 
                                 (data['locality_name'] == 'Санкт-Петербург')]['floor_category'].value_counts()
city_centers_nearest_3_km
# Out:
# другой       174
# последний     70
# первый        53
# Name: floor_category, dtype: int64

# %%
city_centers_nearest_3_km.plot(kind='bar', figsize=(12, 4), title=column, legend=True, grid=True);

# %%
# Изучим объекты недвижимости на расстоянии 5 киллометров до центра
city_centers_nearest_5_km = data[(data['city_centers_nearest_km'] == 5.0) &
                                 (data['locality_name'] == 'Санкт-Петербург')]['floor_category'].value_counts()
city_centers_nearest_5_km
# Out:
# другой       598
# последний    120
# первый        72
# Name: floor_category, dtype: int64

# %%
city_centers_nearest_5_km.plot(kind='bar', figsize=(12, 4), title=column, legend=True, grid=True);

# %% [markdown]
# - Цена объекта недвижимости уменьшается с увеличением расстояния до центра.
# - Аномальные значения на `27`-ом и `41`-ом киллометрах объясняется малым количеством объектов недвижимости на данных расстояниях (`2` объекта и `1` объект соответственно).
# - На расстоянии `3` киллометра до центра можно заметить большое количество объектов расположены на первом этаже, либо на последнем.
# - На расстоянии `5` киллометров до центра можно большинство объектов расположены между первым и последним этажами.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Размер доли категорий квартир с более дешевой стоимостью намного больше на 3-м километре, чем на пятом, что является одной из причин падения и пика...
#
# возможно к этому фактору добавляются и другие

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Импорт библиотек стоит выносить на первые строки проекта, так коллегам будет удобнее настроить свои рабочие места под наши требования

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />✔

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Для выполнения 5-го пункта стоит сгруппировать и найти среднюю стоимость только питерских квартир на каждом километре, на этих данных построить линейный график, где по оси х будут округленные км., а по оси у - средняя стоимость всех квартир на этом км.
#
# Шаг 4.
#
# 5.	Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 27-м км.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# - **Получение данных**:
# Мы получили данные безопасным способом при помощи конструкции `try-except` и изучили их при помощи метода `info()`. Затем мы построили гистограммы по всем числовым столбцам.
# - **Предобработка данных**:
# Полученные данные мы очистили от пропусков и неявных дубликатов. Также мы произвели смену типов там, где это необходимо. Некоторые столбцы мы очистили от аномальных значений.
# - **Добавление дополнительных столбцов**: Добавили дополнительные столбцы в таблицу с данными:
#  * цена одного квадратного метра
#  * день недели публикации объявления
#  * месяц публикации объявления
#  * год публикации объявления
#  * тип этажа квартиры
#  * расстояние до центра города в километрах
# - **Исследовательский анализ данных**: Изучили следующие параметры объектов:
#  * общая площадь
#  * жилая площадь
#  * площадь кухни
#  * цена объекта
#  * количество комнат
#  * высота потолков
#  * этаж квартиры;
#  * тип этажа квартиры
#  * общее количество этажей в доме;
#  * расстояние до центра города в метрах;
#  * расстояние до ближайшего аэропорта;
#  * расстояние до ближайшего парка;
#  * день и месяц публикации объявления.
#
#  Мы построили отдельные гистограммы по всем вышеперечисленным параметрам. Также мы изучили как быстро продавались квартиры и какие факторы больше всего влияют на общую (полную) стоимость объекта:
#  * Продажа объекта обычно занимает от `45` до `248` дней.
#  * Необычно долгими можно считать продажи от `553` дней.
#  * Чаще всего продажа занимает около `45.0` дней.
#  * `total_area`, `living_area`, `kitchen_area`, `rooms`, `floor_category`, `exposition_year` больше всего влияют на общую полную стоимость.
#  * Можно заметить, что квартиры на первом этаже как правило дешевле, чем квартиры на других этажах.
#  * С увеличением количества комнат растёт и цена объекта недвижимости.
#  * Цена на объекты недвижимости уменьшается с каждым годом вплоть до 2018 года. Цена - это параметр, на который влияет несколько других факторов. Например, можно заметить, что количество объявлений росло с 2014 по 2018 годы. Это могло повлиять на изменение цены на рынке недвижимости. Также изменение средней общей площади объектов недвижимости могло повлиять на изменение цен.
#
#
#  Мы посчитали среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений и выделили населённые пункты с самой высокой и низкой стоимостью квадратного метра:
#  * Населённый пункт с самой высокой стоимостью квадратного метра - Санкт-Петербург
#  * Населённый пункт с самой низкой стоимостью квадратного метра - деревня Вахнова Кара
#
#  После этого мы описали, как стоимость объектов зависит от расстояния до центра города:
#  * Цена объекта недвижимости уменьшается с увеличением расстояния до центра.
#  * Аномальные значения на `27`-ом и `41`-ом киллометрах объясняется малым количеством объектов недвижимости на данных расстояниях (`2` объекта и `1` объект соответственно).
#  * На расстоянии `3` киллометра до центра можно заметить большое количество объектов расположены на первом этаже, либо на последнем.
#  * На расстоянии `5` киллометров до центра можно большинство объектов расположены между первым и последним этажами.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец
#
# Критические ❌ комментарии
#
# + настроить фильтрацию редких значений в п. 2.4
# + добавить графики в п. 4.3
# + добавить вывод в п. 4.3
# + добавить график в ТОП-10
# + выполнить п.4.5 и исследовать аномалии
# + поправить итоговый вывод
#
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)
#
# [How to visualise data using histograms in Pandas](https://practicaldatascience.co.uk/data-science/how-to-visualise-data-using-histograms-in-pandas)

# %% [markdown]
# ### Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'city_centers_nearest']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %%
# check
price_pivot_area = data.pivot_table(index='last_price', values=([
    'total_area', 'living_area', 'kitchen_area']), aggfunc='median')
price_pivot_area = price_pivot_area.reset_index()
# Посмотрим на диаграммы рассеяния для столбцов 'total_area', 'living_area', 'kitchen_area'.
for row in ['total_area', 'living_area', 'kitchen_area']:
    sns.relplot(data=price_pivot_area, x='last_price', y=row, kind='scatter')

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'g', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
